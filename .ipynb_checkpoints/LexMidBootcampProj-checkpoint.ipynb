# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Importing and first look at data

# %%
population = pd.read_csv('LGBT_Survey_SubsetSize.csv')
display(population.shape)
population.head()
# Out:
# (29, 7)
#   CountryID      N  Lesbian women  Gay men  Bisexual women  Bisexual men  \
# 0  EU Total  93079          15236    57448            6424          7200
# 1        AT   2543            437     1558             164           217
# 2        BE   2901            424     1998             132           182
# 3        BG   1033            226      474             139            88
# 4        CY    265             41      164              18            17
#
#    Transgender
# 0         6771
# 1          167
# 2          165
# 3          106
# 4           25

# %%
population['CountryID'].nunique()
# Out:
# 29

# %%
population['validate_n'] = population['N'] == (population['Lesbian women'] + population['Gay men'] + population['Bisexual women'] + population['Bisexual men'] + population['Transgender'])
population
# Out:
#    CountryID      N  Lesbian women  Gay men  Bisexual women  Bisexual men  \
# 0   EU Total  93079          15236    57448            6424          7200
# 1         AT   2543            437     1558             164           217
# 2         BE   2901            424     1998             132           182
# 3         BG   1033            226      474             139            88
# 4         CY    265             41      164              18            17
# 5         CZ   2469            565     1432             163           139
# 6         DE  20271           2445    13907             590          2000
# 7         DK   1710            393      930             136           108
# 8         EE    374             99      170              61            20
# 9         GR   2760            399     1590             219           288
# 10        ES   6388            897     4409             354           514
# 11        FI   3439            820     1192             756           190
# 12        FR   8375           1302     5720             326           592
# 13        HU   2267            307     1455             135           236
# 14        IE   1625            423      864             141            58
# 15        IT  13255           2136     8668             805           996
# 16        LT    821            177      439             100            65
# 17        LU    318             51      187              16            26
# 18        LV    501            150      200              83            22
# 19        MT    358            109      173              40            18
# 20        NL   3175            614     1937             214           159
# 21        PL   2790            375     1754             264           138
# 22        PT   2125            456     1168             268           146
# 23        RO   1260            139      690              70           214
# 24        SE   2464            427     1053             341           269
# 25        SI    636            160      345              64            38
# 26        SK   1000            144      584              96            61
# 27        GB   6759           1285     3795             572           294
# 28        HR   1197            235      592             157           105
#
#     Transgender  validate_n
# 0          6771        True
# 1           167        True
# 2           165        True
# 3           106        True
# 4            25        True
# 5           170        True
# 6          1329        True
# 7           143        True
# 8            24        True
# 9           264        True
# 10          214        True
# 11          481        True
# 12          435        True
# 13          134        True
# 14          139        True
# 15          650        True
# 16           40        True
# 17           38        True
# 18           46        True
# 19           18        True
# 20          251        True
# 21          259        True
# 22           87        True
# 23          147        True
# 24          374        True
# 25           29        True
# 26          115        True
# 27          813        True
# 28          108        True

# %%
#There are 28 unique countries of origin in the study and 
#a row with the sum of all countries (EU Total)
#I've checked and validated that the column 'N' is the sum of the subsets per country (ie total population per country)

# %%
#Country codes: some input uses CountryID, others use Country Code, will uniformise and use CountryCode everywhere.

# %%
country_codes = pd.read_excel('QES_country_codes.xlsx', sheet_name='Country_code')
display(country_codes.shape)
country_codes
# Out:
# (29, 3)
#    CountryID     CountryCode    country_code
# 0         AT         Austria         austria
# 1         BE         Belgium         belgium
# 2         BG        Bulgaria        bulgaria
# 3         CY          Cyprus          cyprus
# 4         CZ  Czech_Republic  czech_republic
# 5         DE         Germany         germany
# 6         DK         Denmark         denmark
# 7         EE         Estonia         estonia
# 8         GR          Greece          greece
# 9         ES           Spain           spain
# 10        FI         Finland         finland
# 11        FR          France          france
# 12        HU         Hungary         hungary
# 13        HR         Croatia         croatia
# 14        IE         Ireland         ireland
# 15        IT           Italy           italy
# 16        LT       Lithuania       lithuania
# 17        LU      Luxembourg      luxembourg
# 18        LV          Latvia          latvia
# 19        MT           Malta           malta
# 20        NL     Netherlands     netherlands
# 21        PL          Poland          poland
# 22        PT        Portugal        portugal
# 23        RO         Romania         romania
# 24        SE          Sweden          sweden
# 25        SK        Slovakia        slovakia
# 26        SI        Slovenia        slovenia
# 27        GB  United_Kingdom  united_kingdom
# 28  EU Total        EU_Total        eu_total

# %%
population['CountryID'] = population['CountryID'].map(country_codes.set_index('CountryID')['CountryCode'])
population = population.drop(['validate_n'],axis=1)

# %%
#I was going to clean up the column names (lower case/no space, etc.) but other dataframes use these columns names so doesn't make sense to rename it everywhere!
#Instead just changing names where needed.

# %%
population_clean = population.rename(columns={'CountryID':'CountryCode','Lesbian women': 'Lesbian', 'Gay men':'Gay'})
population_clean.head()
# Out:
#   CountryCode      N  Lesbian    Gay  Bisexual women  Bisexual men  \
# 0    EU_Total  93079    15236  57448            6424          7200
# 1     Austria   2543      437   1558             164           217
# 2     Belgium   2901      424   1998             132           182
# 3    Bulgaria   1033      226    474             139            88
# 4      Cyprus    265       41    164              18            17
#
#    Transgender
# 0         6771
# 1          167
# 2          165
# 3          106
# 4           25

# %%
#I need to melt this table to get the count per country/subset per row, not as pivot table.

# %%
population_vert = population_clean.melt(id_vars=['CountryCode'])
population_vert
# Out:
#         CountryCode     variable  value
# 0          EU_Total            N  93079
# 1           Austria            N   2543
# 2           Belgium            N   2901
# 3          Bulgaria            N   1033
# 4            Cyprus            N    265
# ..              ...          ...    ...
# 169          Sweden  Transgender    374
# 170        Slovenia  Transgender     29
# 171        Slovakia  Transgender    115
# 172  United_Kingdom  Transgender    813
# 173         Croatia  Transgender    108
#
# [174 rows x 3 columns]

# %%
population_vert['country_subset'] = population_vert['CountryCode'] + ' ' +population_vert['variable']
population_vert
# Out:
#         CountryCode     variable  value              country_subset
# 0          EU_Total            N  93079                  EU_Total N
# 1           Austria            N   2543                   Austria N
# 2           Belgium            N   2901                   Belgium N
# 3          Bulgaria            N   1033                  Bulgaria N
# 4            Cyprus            N    265                    Cyprus N
# ..              ...          ...    ...                         ...
# 169          Sweden  Transgender    374          Sweden Transgender
# 170        Slovenia  Transgender     29        Slovenia Transgender
# 171        Slovakia  Transgender    115        Slovakia Transgender
# 172  United_Kingdom  Transgender    813  United_Kingdom Transgender
# 173         Croatia  Transgender    108         Croatia Transgender
#
# [174 rows x 4 columns]

# %%
population_vert['country_subset'].isna().sum()
# Out:
# 0

# %%
#Now I import all "response" data (except for trans specific questions as the "reference population" is different)

# %%
daily_life = pd.read_csv('LGBT_Survey_DailyLife.csv')
discrimination = pd.read_csv('LGBT_Survey_Discrimination.csv')
rights_awareness = pd.read_csv('LGBT_Survey_RightsAwareness.csv')
transgender_specific = pd.read_csv('LGBT_Survey_TransgenderSpecificQuestions.csv')
violence_harassment = pd.read_csv('LGBT_Survey_ViolenceAndHarassment.csv')
data=pd.concat([daily_life,discrimination,rights_awareness,violence_harassment],axis=0)
display(data.shape)
data.head()
# Out:
# (98920, 7)
#   CountryCode   subset question_code  \
# 0     Austria  Lesbian          b1_a
# 1     Austria  Lesbian          b1_a
# 2     Austria  Lesbian          b1_a
# 3     Austria  Lesbian          b1_a
# 4     Austria  Lesbian          b1_a
#
#                                       question_label             answer  \
# 0  In your opinion, how widespread is offensive l...    Very widespread
# 1  In your opinion, how widespread is offensive l...  Fairly widespread
# 2  In your opinion, how widespread is offensive l...        Fairly rare
# 3  In your opinion, how widespread is offensive l...          Very rare
# 4  In your opinion, how widespread is offensive l...         Don`t know
#
#   percentage notes
# 0          8   NaN
# 1         34   NaN
# 2         45   NaN
# 3          9   NaN
# 4          4   [0]

# %%
data = data.drop(['notes'],axis=1)

# %%
#column notes is mostly NaNs and can't be cleaned up, so dropping it.

# %%
#checking if country codes all match our population_vert (needed to match later)

# %%
data['CountryCode'].value_counts()
# Out:
# Average           3583
# Germany           3566
# United Kingdom    3537
# Italy             3534
# Spain             3529
# France            3525
# Sweden            3512
# Finland           3491
# Austria           3487
# Poland            3481
# Netherlands       3475
# Greece            3468
# Czech Republic    3454
# Romania           3452
# Hungary           3446
# Croatia           3442
# Ireland           3437
# Belgium           3432
# Portugal          3432
# Bulgaria          3429
# Denmark           3390
# Slovakia          3368
# Lithuania         3360
# Latvia            3283
# Estonia           3236
# Slovenia          3222
# Cyprus            3160
# Malta             3153
# Luxembourg        3036
# Name: CountryCode, dtype: int64

# %%
#I can see United_kingdom and Czech_republic haven not converted and still have a space in data, need to reformat.
#There's also a CountryCode average that I will drop, as can't calculate response on it.

# %%
data['CountryCode'] = np.where(data['CountryCode'].isin (["United Kingdom"]), "United_Kingdom",data['CountryCode'])
data['CountryCode'] = np.where(data['CountryCode'].isin (["Czech Republic"]), "Czech_Republic",data['CountryCode'])
data = data[data.CountryCode != "Average"]

# %%
data['CountryCode'].value_counts()
# Out:
# Germany           3566
# United_Kingdom    3537
# Italy             3534
# Spain             3529
# France            3525
# Sweden            3512
# Finland           3491
# Austria           3487
# Poland            3481
# Netherlands       3475
# Greece            3468
# Czech_Republic    3454
# Romania           3452
# Hungary           3446
# Croatia           3442
# Ireland           3437
# Belgium           3432
# Portugal          3432
# Bulgaria          3429
# Denmark           3390
# Slovakia          3368
# Lithuania         3360
# Latvia            3283
# Estonia           3236
# Slovenia          3222
# Cyprus            3160
# Malta             3153
# Luxembourg        3036
# Name: CountryCode, dtype: int64

# %%
#just checking

# %%
#Now to get actual response figures!

# %%
data['country_subset'] = data['CountryCode'] + ' ' +data['subset']

# %%
data['pop_subset'] = data['country_subset'].map(population_vert.set_index('country_subset')['value'])

# %%
data.head()
# Out:
#   CountryCode   subset question_code  \
# 0     Austria  Lesbian          b1_a
# 1     Austria  Lesbian          b1_a
# 2     Austria  Lesbian          b1_a
# 3     Austria  Lesbian          b1_a
# 4     Austria  Lesbian          b1_a
#
#                                       question_label             answer  \
# 0  In your opinion, how widespread is offensive l...    Very widespread
# 1  In your opinion, how widespread is offensive l...  Fairly widespread
# 2  In your opinion, how widespread is offensive l...        Fairly rare
# 3  In your opinion, how widespread is offensive l...          Very rare
# 4  In your opinion, how widespread is offensive l...         Don`t know
#
#   percentage   country_subset  pop_subset
# 0          8  Austria Lesbian         437
# 1         34  Austria Lesbian         437
# 2         45  Austria Lesbian         437
# 3          9  Austria Lesbian         437
# 4          4  Austria Lesbian         437

# %%
data.dtypes
# Out:
# CountryCode       object
# subset            object
# question_code     object
# question_label    object
# answer            object
# percentage        object
# country_subset    object
# pop_subset         int64
# response          object
# dtype: object

# %%
#trying to transform percentage to integer but I have a number of rows with ":". Unfortunately I can't do anything with these (it's a large group and I can't just assign them to something without majorely skewing the data).

# %%
data['percentage'].value_counts()
# Out:
# :      10073
# 2       5268
# 1       4869
# 3       4867
# 0       4433
#        ...
# 96       145
# 97        91
# 98        78
# 100       45
# 99        29
# Name: percentage, Length: 102, dtype: int64

# %%
data = data[data.percentage != ":"]

# %%
data['percentage'].value_counts()
# Out:
# 2      5268
# 1      4869
# 3      4867
# 0      4433
# 4      4241
#        ...
# 96      145
# 97       91
# 98       78
# 100      45
# 99       29
# Name: percentage, Length: 101, dtype: int64

# %%
data.percentage = data['percentage'].astype(int)

# %%
data.dtypes
# Out:
# CountryCode       object
# subset            object
# question_code     object
# question_label    object
# answer            object
# percentage         int64
# country_subset    object
# pop_subset         int64
# response          object
# dtype: object

# %%
data['response'] = round(data['pop_subset']*data['percentage']/100)

# %%
data.response = data['response'].astype(int)

# %%
data.head()
# Out:
#   CountryCode   subset question_code  \
# 0     Austria  Lesbian          b1_a
# 1     Austria  Lesbian          b1_a
# 2     Austria  Lesbian          b1_a
# 3     Austria  Lesbian          b1_a
# 4     Austria  Lesbian          b1_a
#
#                                       question_label             answer  \
# 0  In your opinion, how widespread is offensive l...    Very widespread
# 1  In your opinion, how widespread is offensive l...  Fairly widespread
# 2  In your opinion, how widespread is offensive l...        Fairly rare
# 3  In your opinion, how widespread is offensive l...          Very rare
# 4  In your opinion, how widespread is offensive l...         Don`t know
#
#    percentage   country_subset  pop_subset  response
# 0           8  Austria Lesbian         437        35
# 1          34  Austria Lesbian         437       149
# 2          45  Austria Lesbian         437       197
# 3           9  Austria Lesbian         437        39
# 4           4  Austria Lesbian         437        17

# %%
#Now I have a clean set of data with no more NaNs/odd values and the actual number of responses (instead of percentage we had at the start).
# Out:
# (85264, 9)

# %%
round(data.isna().sum()/len(data),4)*100
# Out:
# CountryCode       0.0
# subset            0.0
# question_code     0.0
# question_label    0.0
# answer            0.0
# percentage        0.0
# country_subset    0.0
# pop_subset        0.0
# response          0.0
# dtype: float64

# %%
data_def = data.copy()
data_def
# Out:
#           CountryCode       subset question_code  \
# 0             Austria      Lesbian          b1_a
# 1             Austria      Lesbian          b1_a
# 2             Austria      Lesbian          b1_a
# 3             Austria      Lesbian          b1_a
# 4             Austria      Lesbian          b1_a
# ...               ...          ...           ...
# 45320  United_Kingdom  Transgender         fb2_9
# 45321  United_Kingdom  Transgender         fb2_9
# 45322  United_Kingdom  Transgender         fb2_9
# 45323  United_Kingdom  Transgender         fb2_9
# 45324  United_Kingdom  Transgender         fb2_9
#
#                                           question_label  \
# 0      In your opinion, how widespread is offensive l...
# 1      In your opinion, how widespread is offensive l...
# 2      In your opinion, how widespread is offensive l...
# 3      In your opinion, how widespread is offensive l...
# 4      In your opinion, how widespread is offensive l...
# ...                                                  ...
# 45320  MOST SERIOUS incident of harassment - Do you t...
# 45321  MOST SERIOUS incident of harassment - Do you t...
# 45322  MOST SERIOUS incident of harassment - Do you t...
# 45323  MOST SERIOUS incident of harassment - Do you t...
# 45324  MOST SERIOUS incident of harassment - Do you t...
#
#                          answer  percentage              country_subset  \
# 0               Very widespread           8             Austria Lesbian
# 1             Fairly widespread          34             Austria Lesbian
# 2                   Fairly rare          45             Austria Lesbian
# 3                     Very rare           9             Austria Lesbian
# 4                    Don`t know           4             Austria Lesbian
# ...                         ...         ...                         ...
# 45320                   Lesbian           1  United_Kingdom Transgender
# 45321                       Gay           3  United_Kingdom Transgender
# 45322                  Bisexual           1  United_Kingdom Transgender
# 45323  Mixed sexual orientation           3  United_Kingdom Transgender
# 45324                Don`t know          33  United_Kingdom Transgender
#
#        pop_subset  response
# 0             437        35
# 1             437       149
# 2             437       197
# 3             437        39
# 4             437        17
# ...           ...       ...
# 45320         813         8
# 45321         813        24
# 45322         813         8
# 45323         813        24
# 45324         813       268
#
# [85264 rows x 9 columns]

# %% [markdown]
# # Saving data to.csv

# %%
data_def.to_csv('data_def_20220207.csv')
population_vert.to_csv('population_vert_20220207.csv')

# %% [markdown]
# # 2. Starting EDA with high level stats

# %%
country_counts = population_vert.groupby(['CountryCode']).agg({'value':sum})
country_level = pd.DataFrame(country_counts.reset_index())
country_level = country_level.sort_values(by=['value'],ascending=False)
country_level
# Out:
#        CountryCode   value
# 7         EU_Total  186158
# 11         Germany   40542
# 15           Italy   26510
# 10          France   16750
# 28  United_Kingdom   13518
# 26           Spain   12776
# 9          Finland    6878
# 20     Netherlands    6350
# 1          Belgium    5802
# 21          Poland    5580
# 12          Greece    5520
# 0          Austria    5086
# 5   Czech_Republic    4938
# 27          Sweden    4928
# 13         Hungary    4534
# 22        Portugal    4250
# 6          Denmark    3420
# 14         Ireland    3250
# 23         Romania    2520
# 3          Croatia    2394
# 2         Bulgaria    2066
# 24        Slovakia    2000
# 17       Lithuania    1642
# 25        Slovenia    1272
# 16          Latvia    1002
# 8          Estonia     748
# 19           Malta     716
# 18      Luxembourg     636
# 4           Cyprus     530

# %%
genpop = pd.read_excel('QES_genpop.xlsx')
genpop = genpop.sort_values(by=['Population_2012'], ascending=False)
genpop
# Out:
#        CountryCode  Population_2012
# 5          Germany         80425823
# 11          France         65659814
# 27  United_Kingdom         63700215
# 15           Italy         59539717
# 9            Spain         46773055
# 21          Poland         38063164
# 23         Romania         20058035
# 20     Netherlands         16754962
# 1          Belgium         11106932
# 8           Greece         11045011
# 22        Portugal         10514844
# 4   Czech_Republic         10510785
# 12         Hungary          9920362
# 24          Sweden          9519374
# 0          Austria          8429991
# 2         Bulgaria          7305888
# 6          Denmark          5591572
# 10         Finland          5413971
# 25        Slovakia          5407579
# 14         Ireland          4599533
# 13         Croatia          4267558
# 16       Lithuania          2987773
# 26        Slovenia          2057159
# 18          Latvia          2034319
# 7          Estonia          1322696
# 3           Cyprus          1135046
# 17      Luxembourg           530946
# 19           Malta           420028

# %%
genpop['sample'] = genpop['CountryCode'].map(country_level.set_index('CountryCode')['value'])
genpop['respondents_country']= genpop['sample']/genpop['Population_2012']*100
genpop = genpop.sort_values(by=['respondents_country'], ascending=False)
genpop
# Out:
#        CountryCode  Population_2012  sample  respondents_country
# 19           Malta           420028     716             0.170465
# 10         Finland          5413971    6878             0.127042
# 17      Luxembourg           530946     636             0.119786
# 14         Ireland          4599533    3250             0.070659
# 26        Slovenia          2057159    1272             0.061833
# 6          Denmark          5591572    3420             0.061163
# 0          Austria          8429991    5086             0.060332
# 7          Estonia          1322696     748             0.056551
# 13         Croatia          4267558    2394             0.056098
# 16       Lithuania          2987773    1642             0.054957
# 1          Belgium         11106932    5802             0.052238
# 24          Sweden          9519374    4928             0.051768
# 5          Germany         80425823   40542             0.050409
# 8           Greece         11045011    5520             0.049977
# 18          Latvia          2034319    1002             0.049255
# 4   Czech_Republic         10510785    4938             0.046980
# 3           Cyprus          1135046     530             0.046694
# 12         Hungary          9920362    4534             0.045704
# 15           Italy         59539717   26510             0.044525
# 22        Portugal         10514844    4250             0.040419
# 20     Netherlands         16754962    6350             0.037899
# 25        Slovakia          5407579    2000             0.036985
# 2         Bulgaria          7305888    2066             0.028279
# 9            Spain         46773055   12776             0.027315
# 11          France         65659814   16750             0.025510
# 27  United_Kingdom         63700215   13518             0.021221
# 21          Poland         38063164    5580             0.014660
# 23         Romania         20058035    2520             0.012564

# %%
#create visualization in tableau for background (map?)

# %%
subset_counts = population_vert.groupby(['variable']).agg({'value':sum})
subset_counts = pd.DataFrame(subset_counts.reset_index())
subset_counts = subset_counts.sort_values(by=['value'],ascending=False)
subset_counts
# Out:
#          variable   value
# 4               N  186158
# 2             Gay  114896
# 3         Lesbian   30472
# 0    Bisexual men   14400
# 5     Transgender   13542
# 1  Bisexual women   12848

# %%
#create visualization in tableau for background (explain assumptions about bias)
