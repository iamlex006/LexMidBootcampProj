# %%
import pandas as pd
import numpy as np

# %%
data_def = pd.read_csv('data_def_20220208.csv')
display(data_def.head())
population_vert = pd.read_csv('population_vert_20220208.csv')
display(population_vert.head())
# Out:
#    Unnamed: 0 CountryCode   subset question_code  \
# 0           0     Austria  Lesbian          b1_a
# 1           1     Austria  Lesbian          b1_a
# 2           2     Austria  Lesbian          b1_a
# 3           3     Austria  Lesbian          b1_a
# 4           4     Austria  Lesbian          b1_a
#
#                                       question_label             answer  \
# 0  In your opinion, how widespread is offensive l...    Very widespread
# 1  In your opinion, how widespread is offensive l...  Fairly widespread
# 2  In your opinion, how widespread is offensive l...        Fairly rare
# 3  In your opinion, how widespread is offensive l...          Very rare
# 4  In your opinion, how widespread is offensive l...         Don`t know
#
#    percentage   country_subset  pop_subset  response
# 0           8  Austria Lesbian         437        35
# 1          34  Austria Lesbian         437       149
# 2          45  Austria Lesbian         437       197
# ...

# %% [markdown]
# # Starting EDA with high level stats¶

# %%
country_counts = population_vert.groupby(['CountryCode']).agg({'value':sum})
country_level = pd.DataFrame(country_counts.reset_index())
country_level = country_level[country_level.CountryCode != 'EU_Total']
country_level = country_level.sort_values(by=['value'],ascending=False)
country_level
# Out:
#        CountryCode  value
# 11         Germany  40542
# 15           Italy  26510
# 10          France  16750
# 28  United_Kingdom  13518
# 26           Spain  12776
# 9          Finland   6878
# 20     Netherlands   6350
# 1          Belgium   5802
# 21          Poland   5580
# 12          Greece   5520
# 0          Austria   5086
# 5   Czech_Republic   4938
# 27          Sweden   4928
# 13         Hungary   4534
# 22        Portugal   4250
# 6          Denmark   3420
# 14         Ireland   3250
# 23         Romania   2520
# 3          Croatia   2394
# 2         Bulgaria   2066
# 24        Slovakia   2000
# 17       Lithuania   1642
# 25        Slovenia   1272
# 16          Latvia   1002
# 8          Estonia    748
# 19           Malta    716
# 18      Luxembourg    636
# 4           Cyprus    530

# %%
genpop = pd.read_excel('QES_genpop.xlsx')
genpop = genpop.sort_values(by=['Population_2012'], ascending=False)
genpop
# Out:
#        CountryCode  Population_2012
# 5          Germany         80425823
# 11          France         65659814
# 27  United_Kingdom         63700215
# 15           Italy         59539717
# 9            Spain         46773055
# 21          Poland         38063164
# 23         Romania         20058035
# 20     Netherlands         16754962
# 1          Belgium         11106932
# 8           Greece         11045011
# 22        Portugal         10514844
# 4   Czech_Republic         10510785
# 12         Hungary          9920362
# 24          Sweden          9519374
# 0          Austria          8429991
# 2         Bulgaria          7305888
# 6          Denmark          5591572
# 10         Finland          5413971
# 25        Slovakia          5407579
# 14         Ireland          4599533
# 13         Croatia          4267558
# 16       Lithuania          2987773
# 26        Slovenia          2057159
# 18          Latvia          2034319
# 7          Estonia          1322696
# ...

# %%
genpop['sample'] = genpop['CountryCode'].map(country_level.set_index('CountryCode')['value'])
genpop['respondents_country']= genpop['sample']/genpop['Population_2012']*100
genpop = genpop.sort_values(by=['respondents_country'], ascending=False)
genpop.to_csv('genpop.csv')
genpop
# Out:
#        CountryCode  Population_2012  sample  respondents_country
# 19           Malta           420028     716             0.170465
# 10         Finland          5413971    6878             0.127042
# 17      Luxembourg           530946     636             0.119786
# 14         Ireland          4599533    3250             0.070659
# 26        Slovenia          2057159    1272             0.061833
# 6          Denmark          5591572    3420             0.061163
# 0          Austria          8429991    5086             0.060332
# 7          Estonia          1322696     748             0.056551
# 13         Croatia          4267558    2394             0.056098
# 16       Lithuania          2987773    1642             0.054957
# 1          Belgium         11106932    5802             0.052238
# 24          Sweden          9519374    4928             0.051768
# 5          Germany         80425823   40542             0.050409
# ...

# %%
#create visualization in tableau for background (map?)

# %%
population_selected = population_vert[population_vert.CountryCode != 'EU_Total']
subset_counts = population_selected.groupby(['variable']).agg({'value':sum})
subset_counts = pd.DataFrame(subset_counts.reset_index())
subset_counts = subset_counts.sort_values(by=['value'],ascending=False)
subset_counts.to_csv('subset_counts.csv')
subset_counts
# Out:
#          variable  value
# 4               N  93079
# 2             Gay  57448
# 3         Lesbian  15236
# 0    Bisexual men   7200
# 5     Transgender   6771
# 1  Bisexual women   6424

# %%
#create visualization in tableau for background (explain assumptions about bias)

# %% [markdown]
# # Get overview of all questions

# %%
question_list = data_def[['question_code','question_label']]
quest_list_deduped = question_list.drop_duplicates(subset='question_code', keep='first', inplace=False)
quest_list_deduped
# Out:
#       question_code                                     question_label
# 0              b1_a  In your opinion, how widespread is offensive l...
# 675            b1_b  In your opinion, how widespread are casual jok...
# 1350           b1_c  In your opinion, how widespread are expression...
# 2025           b1_d  In your opinion, how widespread are assaults a...
# 2700           b1_e  In your opinion, how widespread is same-sex pa...
# ...             ...                                                ...
# 87850         tr8_e  Prove hormonal treatment (started or finished)...
# 87916         tr8_f  Undergo mandatory psychotherapy / psychiatric ...
# 87982         tr8_g  Prove medical/psychological diagnosis of trans...
# 88048         tr8_h  Other - As far as you know, what would you hav...
# 88114           tr9  Do you avoid expressing your gender (or your d...
#
# [164 rows x 2 columns]

# %%
quest_list_deduped.to_excel('quest_list.xlsx')

# %%
#Getting some overview tables from MySQL

# %%
import pymysql
from sqlalchemy import create_engine
import getpass

# %%
password = getpass.getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/QES_project'
engine = create_engine(connection_string)

# %%
query = '''SELECT CountryCode, question_code, question_label,answer,SUM(response)
FROM res_all
GROUP BY question_code,question_label, answer,CountryCode;'''

all_answers = pd.read_sql_query(query, engine)
all_answers.head()
# Out:
#   CountryCode question_code  \
# 0     Austria          b1_a
# 1     Austria          b1_a
# 2     Austria          b1_a
# 3     Austria          b1_a
# 4     Austria          b1_a
#
#                                       question_label             answer  \
# 0  In your opinion, how widespread is offensive l...    Very widespread
# 1  In your opinion, how widespread is offensive l...  Fairly widespread
# 2  In your opinion, how widespread is offensive l...        Fairly rare
# 3  In your opinion, how widespread is offensive l...          Very rare
# 4  In your opinion, how widespread is offensive l...         Don`t know
#
#    SUM(response)
# 0          131.0
# 1          609.0
# 2         1273.0
# 3          431.0
# 4          119.0

# %%
all_answers['percent_all'] = round(all_answers['SUM(response)']/93079*100,2)
all_answers.head()
# Out:
#   CountryCode question_code  \
# 0     Austria          b1_a
# 1     Austria          b1_a
# 2     Austria          b1_a
# 3     Austria          b1_a
# 4     Austria          b1_a
#
#                                       question_label             answer  \
# 0  In your opinion, how widespread is offensive l...    Very widespread
# 1  In your opinion, how widespread is offensive l...  Fairly widespread
# 2  In your opinion, how widespread is offensive l...        Fairly rare
# 3  In your opinion, how widespread is offensive l...          Very rare
# 4  In your opinion, how widespread is offensive l...         Don`t know
#
#    SUM(response)  percent_all
# 0          131.0         0.14
# 1          609.0         0.65
# 2         1273.0         1.37
# 3          431.0         0.46
# 4          119.0         0.13

# %%
all_answers.to_excel('all_answers.xlsx')

# %% [markdown]
# # Looking in more detail, selecting questions to treat and what data is needed for each.

# %%
b1_ab = all_answers[all_answers['question_code'].isin(['b1_a','b1_b'])]
b1_ab = b1_ab.groupby(['answer']).agg({"SUM(response)":sum})
b1_ab = pd.DataFrame(b1_ab)
b1_ab['percent'] = round(b1_ab['SUM(response)']/186158*100,2)
b1_ab = b1_ab.sort_values(by=['percent'],ascending=False)
b1_ab.to_csv('b1_ab.csv')
b1_ab
# Out:
#                    SUM(response)  percent
# answer
# Fairly widespread        65552.0    35.21
# Fairly rare              49575.0    26.63
# Very widespread          46368.0    24.91
# Very rare                20590.0    11.06
# Don`t know                3997.0     2.15

# %%
b1_cd = all_answers[all_answers['question_code'].isin(['b1_c','b1_d'])]
b1_cd = b1_cd.groupby(['answer']).agg({"SUM(response)":sum})
b1_cd = pd.DataFrame(b1_cd)
b1_cd['percent'] = round(b1_cd['SUM(response)']/186158*100,2)
b1_cd = b1_cd.sort_values(by=['percent'],ascending=False)
b1_cd.to_csv('b1_cd.csv')
b1_cd
# Out:
#                    SUM(response)  percent
# answer
# Fairly rare              79352.0    42.63
# Fairly widespread        60700.0    32.61
# Very rare                20404.0    10.96
# Very widespread          18919.0    10.16
# Don`t know                6722.0     3.61

# %%
g4 = all_answers[all_answers['question_code'].isin(['g4_a','g4_b'])]
g4 = g4.groupby(['answer']).agg({"SUM(response)":sum})
g4 = pd.DataFrame(g4)
g4['percent'] = round(g4['SUM(response)']/186158*100,2)
g4 = g4.sort_values(by=['percent'],ascending=False)
g4.to_csv('g4.csv')
g4
# Out:
#                                            SUM(response)  percent
# answer
# Never happened in the last sixth months         128944.0    69.27
# Happened only once in the last six months        22967.0    12.34
# 2-5 times in the last six months                 15144.0     8.14
# Don`t know                                       13924.0     7.48
# 6 times or more in the last six months            5127.0     2.75

# %%
b1_ef = all_answers[all_answers['question_code'].isin(['b1_e','b1_f'])]
b1_ef = pd.DataFrame(b1_ef)
b1_ef.to_csv('b1_ef.csv')
b1_ef
# Out:
#         CountryCode question_code  \
# 560         Austria          b1_e
# 561         Austria          b1_e
# 562         Austria          b1_e
# 563         Austria          b1_e
# 564         Austria          b1_e
# ..              ...           ...
# 835  United_Kingdom          b1_f
# 836  United_Kingdom          b1_f
# 837  United_Kingdom          b1_f
# 838  United_Kingdom          b1_f
# 839  United_Kingdom          b1_f
#
#                                         question_label             answer  \
# 560  In your opinion, how widespread is same-sex pa...    Very widespread
# 561  In your opinion, how widespread is same-sex pa...  Fairly widespread
# 562  In your opinion, how widespread is same-sex pa...        Fairly rare
# 563  In your opinion, how widespread is same-sex pa...          Very rare
# 564  In your opinion, how widespread is same-sex pa...         Don`t know
# ..                                                 ...                ...
# ...

# %%
b2 = all_answers[all_answers['question_code'].isin(['b2_a','b2_b','b2_c','b2_c','b2_d','b2_e','b2_f','b2_g','b2_h'])]
b2 = pd.DataFrame(b2)
b2.to_csv('b2.csv')
b2
# Out:
#          CountryCode question_code  \
# 1260         Austria          b2_a
# 1261         Austria          b2_a
# 1262         Austria          b2_a
# 1263         Austria          b2_a
# 1264         Austria          b2_a
# ...              ...           ...
# 2599  United_Kingdom          b2_h
# 2600  United_Kingdom          b2_h
# 2601  United_Kingdom          b2_h
# 2602  United_Kingdom          b2_h
# 2603  United_Kingdom          b2_h
#
#                                          question_label  \
# 1260  What would allow you to be more comfortable li...
# 1261  What would allow you to be more comfortable li...
# 1262  What would allow you to be more comfortable li...
# 1263  What would allow you to be more comfortable li...
# 1264  What would allow you to be more comfortable li...
# ...                                                 ...
# 2599  What would allow you to be more comfortable li...
# 2600  What would allow you to be more comfortable li...
# ...

# %%
c2 = all_answers[all_answers['question_code'].isin(['c2_c','c2a_a','c2a_b','c2a_c','c2a_d'])]
c2 = pd.DataFrame(c2)
c2.to_csv('c2.csv')
c2
# Out:
#          CountryCode question_code  \
# 7096         Austria         c2a_a
# 7097         Austria         c2a_a
# 7098         Austria         c2a_a
# 7099         Belgium         c2a_a
# 7100         Belgium         c2a_a
# ...              ...           ...
# 7538        Slovakia          c2_c
# 7539        Slovakia          c2_c
# 7540  United_Kingdom          c2_c
# 7541  United_Kingdom          c2_c
# 7542  United_Kingdom          c2_c
#
#                                          question_label      answer  \
# 7096  In the last 12 months, in the country where yo...         Yes
# 7097  In the last 12 months, in the country where yo...          No
# 7098  In the last 12 months, in the country where yo...  Don`t know
# 7099  In the last 12 months, in the country where yo...         Yes
# 7100  In the last 12 months, in the country where yo...          No
# ...                                                 ...         ...
# ...

# %%
c4 = all_answers[all_answers['question_code'].isin(['c4_a','c4_b','c4_c','c4_d','c4_e','c4_f','c4_g','c4_h','c4_i','c4_j','c4_k'])]
c4 = pd.DataFrame(c4)
c4.to_csv('c4.csv')
c4
# Out:
#          CountryCode question_code  \
# 7543         Austria          c4_a
# 7544         Austria          c4_a
# 7545         Austria          c4_a
# 7546         Belgium          c4_a
# 7547         Belgium          c4_a
# ...              ...           ...
# 8462        Slovakia          c4_k
# 8463        Slovakia          c4_k
# 8464  United_Kingdom          c4_k
# 8465  United_Kingdom          c4_k
# 8466  United_Kingdom          c4_k
#
#                                          question_label      answer  \
# 7543  During the last 12 months, have you personally...         Yes
# 7544  During the last 12 months, have you personally...          No
# 7545  During the last 12 months, have you personally...  Don`t know
# 7546  During the last 12 months, have you personally...         Yes
# 7547  During the last 12 months, have you personally...          No
# ...                                                 ...         ...
# ...

# %%
query = '''SELECT CountryCode, question_code, question_label,answer,SUM(response)
FROM res_all
GROUP BY question_code,question_label, answer,CountryCode;'''

g2_input = pd.read_sql_query(query, engine)
g2_input.head()
# Out:
#   CountryCode question_code  \
# 0     Austria          b1_a
# 1     Austria          b1_a
# 2     Austria          b1_a
# 3     Austria          b1_a
# 4     Austria          b1_a
#
#                                       question_label             answer  \
# 0  In your opinion, how widespread is offensive l...    Very widespread
# 1  In your opinion, how widespread is offensive l...  Fairly widespread
# 2  In your opinion, how widespread is offensive l...        Fairly rare
# 3  In your opinion, how widespread is offensive l...          Very rare
# 4  In your opinion, how widespread is offensive l...         Don`t know
#
#    SUM(response)
# 0          131.0
# 1          609.0
# 2         1273.0
# 3          431.0
# 4          119.0

# %%
g2 = g2_input[g2_input['question_code'].isin(['g2_a','g2_b','g2_c','g2_d'])]
g2 = g2.groupby(['answer','CountryCode']).agg({"SUM(response)":sum})
g2 = pd.DataFrame(g2)
g2.to_csv('g2.csv')
g2
# Out:
#                        SUM(response)
# answer CountryCode
# A few  Austria                2398.0
#        Belgium                2110.0
#        Bulgaria               1240.0
#        Croatia                1428.0
#        Cyprus                  272.0
# ...                              ...
# None   Slovakia               1114.0
#        Slovenia                578.0
#        Spain                  4535.0
#        Sweden                 2098.0
#        United_Kingdom         4390.0
#
# [140 rows x 1 columns]

# %%
g2_pivot = g2.pivot_table(index= ['CountryCode'],columns=['answer'])
g2_pivot.to_csv('g2_pivot.csv')
g2_pivot
# Out:
#                SUM(response)
# answer                 A few      All Don`t know     Most     None
# CountryCode
# Austria               2398.0   3125.0      440.0   2370.0   1841.0
# Belgium               2110.0   4716.0      434.0   2711.0   1603.0
# Bulgaria              1240.0    481.0      334.0    713.0   1369.0
# Croatia               1428.0    558.0      243.0    857.0   1707.0
# Cyprus                 272.0     92.0       42.0    144.0    267.0
# Czech_Republic        2668.0   2363.0      469.0   2414.0   1969.0
# Denmark                967.0   3114.0      265.0   1545.0    940.0
# Estonia                393.0    188.0       94.0    348.0    377.0
# Finland               3053.0   3464.0     1022.0   3110.0   3160.0
# France                7535.0  10766.0     1566.0   7471.0   6260.0
# Germany              17624.0  28142.0     2868.0  18537.0  13940.0
# Greece                3463.0   1288.0      544.0   1736.0   3993.0
# ...

# %%
e12 = all_answers[all_answers['question_code'].isin(['e1','e2'])]
e12 = pd.DataFrame(e12)
e12.to_csv('e12.csv')
e12
# Out:
#           CountryCode question_code  \
# 10847         Austria            e1
# 10848         Austria            e1
# 10849         Austria            e1
# 10850         Austria            e1
# 10851         Belgium            e1
# ...               ...           ...
# 11038        Slovakia            e2
# 11039        Slovakia            e2
# 11040  United_Kingdom            e2
# 11041  United_Kingdom            e2
# 11042  United_Kingdom            e2
#
#                                           question_label  \
# 10847  Do you avoid holding hands in public with a sa...
# 10848  Do you avoid holding hands in public with a sa...
# 10849  Do you avoid holding hands in public with a sa...
# 10850  Do you avoid holding hands in public with a sa...
# 10851  Do you avoid holding hands in public with a sa...
# ...                                                  ...
# 11038  Do you avoid certain places or locations for f...
# 11039  Do you avoid certain places or locations for f...
# ...

# %%
f1_ab = all_answers[all_answers['question_code'].isin(['f1_a','f1_b'])]
f1_ab = pd.DataFrame(f1_ab)
f1_ab.to_csv('f1_ab.csv')
f1_ab
# Out:
#           CountryCode question_code  \
# 11323         Austria          f1_a
# 11324         Austria          f1_a
# 11325         Belgium          f1_a
# 11326         Belgium          f1_a
# 11327        Bulgaria          f1_a
# ...               ...           ...
# 11430        Slovenia          f1_b
# 11431        Slovakia          f1_b
# 11432        Slovakia          f1_b
# 11433  United_Kingdom          f1_b
# 11434  United_Kingdom          f1_b
#
#                                           question_label answer  \
# 11323  In the last 5 years, have you been: physically...    Yes
# 11324  In the last 5 years, have you been: physically...     No
# 11325  In the last 5 years, have you been: physically...    Yes
# 11326  In the last 5 years, have you been: physically...     No
# 11327  In the last 5 years, have you been: physically...    Yes
# ...                                                  ...    ...
# 11430  In the last 5 years, have you been: personally...     No
# ...

# %%
f1_ab_country = g2_input[g2_input['question_code'].isin(['f1_a','f1_b'])]
f1_ab_country = f1_ab_country.groupby(['question_code','answer','CountryCode']).agg({"SUM(response)":sum})
f1_ab_country = pd.DataFrame(f1_ab_country)
f1_ab_country.to_csv('f1_ab_country.csv')
f1_ab_country
# Out:
#                                      SUM(response)
# question_code answer CountryCode
# f1_a          No     Austria                1955.0
#                      Belgium                2141.0
#                      Bulgaria                709.0
#                      Croatia                 775.0
#                      Cyprus                  174.0
# ...                                            ...
# f1_b          Yes    Slovakia                538.0
#                      Slovenia                316.0
#                      Spain                  2441.0
#                      Sweden                 1248.0
#                      United_Kingdom         3731.0
#
# [112 rows x 1 columns]

# %% [markdown]
# # Hypothesis testing

# %%
#Given the type of data I have, I will be doing a hypothesis based on proportions.

# %%
#After some research I found an example of hypothesis testing on proportion, comparing 2 populations. 
# https://sonalake.com/latest/hypothesis-testing-of-proportion-based-samples/

# %%
#I want to compare the proportion of males in the survey population with the proportion of males in the EU population that same year.
#My 0 hypothesis is that the proportion of males is identical between the survey and the EU population.

# %%
from statsmodels.stats.proportion import proportions_ztest
import numpy as np

significance = 0.05

sample_male_eu, sample_size_eu = (356062, 739225)
sample_male_survey, sample_size_survey = (64648, 93079)

males = np.array([sample_male_eu, sample_male_survey])
samples = np.array([sample_size_eu, sample_size_survey])

stat, p_value = proportions_ztest(count=males, nobs=samples,  alternative='two-sided')

print('z_stat: %0.3f, p_value: %0.3f' % (stat, p_value))
if p_value > significance:
   print ("Fail to reject the null hypothesis - we have nothing else to say")
else:
   print ("Reject the null hypothesis - suggest the alternative hypothesis is true")
# Out:
# z_stat: -122.424, p_value: 0.000
# Reject the null hypothesis - suggest the alternative hypothesis is true

# %%
# We can reject the 0 hypothesis and since the z_stat is negative we can infer that the proportion of males in the EU population is (significantly) smaller than in the survey population.
